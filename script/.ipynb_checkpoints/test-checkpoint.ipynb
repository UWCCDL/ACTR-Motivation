# %%
from simon_device0 import *
import actr
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ACT-R connection has been started.

# %%
class SimonTask:
    """A simple version of the Stroop task"""

    def __init__(self, stimuli=generate_stimuli(), setup=False):
        """Initializes a Stroop task (if there are stimuli)"""
        if len(stimuli) > 0:
            self.stimuli = stimuli
            if setup:
                self.setup()

    def setup(self, win=None):
        """Sets up and prepares for first trial"""
        self.window = win
        self.index = 0
        self.log = []
        self.phase = "fixation"
        self.trial_trace = True
        self.current_trial = SimonTrial(self.stimuli[self.index])
    
    def accept_response(self, model, response):
        """A valid response is a key pressed during the 'stimulus' phase"""
        if self.phase == "stimulus":
            self.current_trial.response = response
        #print("in accept_response()", response, self.current_trial.response)
            #actr.schedule_event_now("stroop-next")
    
    def update(self, time=10):
        if self.phase=="done":
            print("done")
        elif self.phase=="fixation":
            self.fixation()
            actr.run(time)
            self.phase="cue"
            self.update()
        elif self.phase=="cue":
            self.cue()
            actr.run(time)
            self.phase="stimulus"
            self.update()
        elif self.phase=="stimulus":
            self.current_trial.offset = actr.mp_time()
            #print('self.current_trial.offset', self.current_trial.offset)
            actr.add_command("stroop-accept-response", task.accept_response, "Accepts a response for the Stroop task")
            actr.monitor_command("output-key", "stroop-accept-response")
            self.stimulus()
            
            actr.run(time)
            
            actr.remove_command_monitor("output-key", "stroop-accept-response")
            actr.remove_command("stroop-accept-response")
            
            
            self.index += 1
            self.log.append(self.current_trial)
            if self.index >= len(self.stimuli):
                self.phase = "done"
            else:
                self.current_trial = SimonTrial(self.stimuli[self.index])
                self.phase = "fixation"
            self.update()
            
    def fixation(self):
        #print("in fixation", self.phase)
        actr.clear_exp_window()
        item = actr.add_text_to_exp_window(self.window, "+", font_size=50,
                                                       x=400, y=300,
                                                       color="black")
        self.current_trial.onset = actr.mp_time()
        #print('self.current_trial.onset', self.current_trial.onset)
        
        stim = self.current_trial.stimulus
        shape = stim.shape.upper()
        location = stim.location.upper()
        kind = stim.kind.upper()
        cue = stim.cue.upper()
        cue_kind = stim.cue_kind.upper()

        print("NEW %s SIMON TRIAL: (SHAPE %s LOCATION %s CUE %s [%s])" % (kind, shape, location, cue, cue_kind))
        
    def cue(self):
        #print("in cue", self.phase)
        actr.clear_exp_window()
        cue = self.current_trial.stimulus.cue
        item = actr.add_visicon_features(
                        ['isa', ['simon-stimulus-location', 'simon-cue'], 'kind', 'simon-cue',
                         'screen-x', 400, 'screen-y', 300,
                         'shape', None, 'color', 'black', 'cue', cue])

    def stimulus(self):
        #print("in stimulus", self.phase)
        
        actr.clear_exp_window()
        shape = self.current_trial.stimulus.shape
        location = self.current_trial.stimulus.location
        item = actr.add_visicon_features(
                        ['isa', ['simon-stimulus-location', 'simon-stimulus'], 'kind', 'simon-stimulus',
                         'screen-x', 200, 'screen-y', 300,
                         'shape', shape, 'color', 'black', 'location', location])
        for i, shape in enumerate(SIMON_MAPPINGS):
            item = actr.add_text_to_exp_window(self.window,
                                               RESPONSE_MAPPINGS[SIMON_MAPPINGS[shape]],
                                               x=600 + i * 50,
                                               y=500)
            
    def done(self):

# %%
load_model("simon-model2")
win = actr.open_exp_window("* SIMON TASK *", width=800, height=600, visible=1)
actr.install_device(win)
task = SimonTask(setup=False)
task.setup(win)
# Out:
# ######### LOADED MODEL COMPETITIVE-SIMON-PY #########
# >> {'seed': [100, 0], 'ans': 0.5, 'le': 0.63, 'mas': 4.0, 'egs': 0.1, 'alpha': 0.1, 'imaginal-activation': 3.0, 'motor-feature-prep-time': 0.02} <<

# %%
task.update()
# Out:
# NEW CONGRUENT SIMON TRIAL: (SHAPE CIRCLE LOCATION LEFT CUE LEFT [VALID])
#      0.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION0 NIL
#      0.050   PROCEDURAL             PRODUCTION-FIRED PREPARE-WM
#      0.050   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK0
#      0.100   PROCEDURAL             PRODUCTION-FIRED FIND-SCREEN
#      0.185   VISION                 SET-BUFFER-CHUNK VISUAL TEXT0
#      0.250   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK1
#      0.300   PROCEDURAL             PRODUCTION-FIRED PROCESS-FIXATION
#      0.300   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK2
#      0.300   ------                 Stopped because no events left to process
#      0.300   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION SIMON-STIMULUS-LOCATION0 NIL
#      0.435   PROCEDURAL             PRODUCTION-FIRED FIND-SCREEN
#      0.520   VISION                 SET-BUFFER-CHUNK VISUAL SIMON-CUE0
#      0.570   PROCEDURAL             PRODUCTION-FIRED PROCESS-CUE
#      0.570   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK3
#      0.570   ------                 Stopped because no events left to process
#      0.570   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION SIMON-STIMULUS-LOCATION1 NIL
#      0.620   PROCEDURAL             PRODUCTION-FIRED FIND-SCREEN
#      0.705   VISION                 SET-BUFFER-CHUNK VISUAL SIMON-STIMULUS0
#      0.755   PROCEDURAL             PRODUCTION-FIRED DONT-PROCESS-SHAPE
#      0.805   PROCEDURAL             PRODUCTION-FIRED DONT-PROCESS-LOCATION
#      0.855   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-INTENDED-RESPONSE
#      0.855   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK4
#      0.883   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CIRCLE-LEFT
#      0.933   PROCEDURAL             PRODUCTION-FIRED CHECK-PASS
#      0.933   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK5
#      0.983   PROCEDURAL             PRODUCTION-FIRED RESPOND
#      0.983   MOTOR                  PUNCH HAND LEFT FINGER INDEX
#      1.243   PROCEDURAL             PRODUCTION-FIRED PREPARE-WM
#      1.243   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK6
#      1.443   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK7
#      1.443   ------                 Stopped because no events left to process
# NEW CONGRUENT SIMON TRIAL: (SHAPE SQUARE LOCATION RIGHT CUE RIGHT [VALID])
#      1.443   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION3 NIL
#      1.493   PROCEDURAL             PRODUCTION-FIRED FIND-SCREEN
#      1.578   VISION                 SET-BUFFER-CHUNK VISUAL TEXT1
#      1.628   PROCEDURAL             PRODUCTION-FIRED PROCESS-FIXATION
#      1.628   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK8
#      1.628   ------                 Stopped because no events left to process
#      1.628   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION SIMON-STIMULUS-LOCATION2 NIL
#      1.763   PROCEDURAL             PRODUCTION-FIRED FIND-SCREEN
#      1.848   VISION                 SET-BUFFER-CHUNK VISUAL SIMON-CUE1
#      1.898   PROCEDURAL             PRODUCTION-FIRED PROCESS-CUE
#      1.898   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK9
#      1.898   ------                 Stopped because no events left to process
#      1.898   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION SIMON-STIMULUS-LOCATION3 NIL
#      1.948   PROCEDURAL             PRODUCTION-FIRED FIND-SCREEN
#      2.033   VISION                 SET-BUFFER-CHUNK VISUAL SIMON-STIMULUS1
#      2.083   PROCEDURAL             PRODUCTION-FIRED PROCESS-LOCATION
#      2.133   PROCEDURAL             PRODUCTION-FIRED DONT-PROCESS-SHAPE
#      2.183   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-INTENDED-RESPONSE
#      2.183   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK10
#      2.285   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL SQUARE-RIGHT
#      2.335   PROCEDURAL             PRODUCTION-FIRED CHECK-PASS
#      2.335   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK11
#      2.385   PROCEDURAL             PRODUCTION-FIRED RESPOND
#      2.385   MOTOR                  PUNCH HAND RIGHT FINGER INDEX
#      2.625   PROCEDURAL             PRODUCTION-FIRED PREPARE-WM
#      2.625   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK12
#      2.825   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK13
#      2.825   ------                 Stopped because no events left to process
# done

# %%
while task.phase != "done":
    task.update()
    task.update()    
    task.update()
# Out:
# NEW CONGRUENT SIMON TRIAL: (SHAPE CIRCLE LOCATION LEFT CUE LEFT [VALID])
#      0.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION0 NIL
#      0.050   PROCEDURAL             PRODUCTION-FIRED PREPARE-WM
#      0.050   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK0
#      0.100   PROCEDURAL             PRODUCTION-FIRED FIND-SCREEN
#      0.185   VISION                 SET-BUFFER-CHUNK VISUAL TEXT0
#      0.250   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK1
#      0.300   PROCEDURAL             PRODUCTION-FIRED PROCESS-FIXATION
#      0.300   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK2
#      0.300   ------                 Stopped because no events left to process
#      0.300   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION SIMON-STIMULUS-LOCATION0 NIL
#      0.435   PROCEDURAL             PRODUCTION-FIRED FIND-SCREEN
#      0.520   VISION                 SET-BUFFER-CHUNK VISUAL SIMON-CUE0
#      0.570   PROCEDURAL             PRODUCTION-FIRED PROCESS-CUE
#      0.570   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK3
#      0.570   ------                 Stopped because no events left to process
#      0.570   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION SIMON-STIMULUS-LOCATION1 NIL
#      0.620   PROCEDURAL             PRODUCTION-FIRED FIND-SCREEN
#      0.705   VISION                 SET-BUFFER-CHUNK VISUAL SIMON-STIMULUS0
#      0.755   PROCEDURAL             PRODUCTION-FIRED DONT-PROCESS-SHAPE
#      0.805   PROCEDURAL             PRODUCTION-FIRED DONT-PROCESS-LOCATION
#      0.855   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-INTENDED-RESPONSE
#      0.855   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK4
#      0.883   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CIRCLE-LEFT
#      0.933   PROCEDURAL             PRODUCTION-FIRED CHECK-PASS
#      0.933   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK5
#      0.983   PROCEDURAL             PRODUCTION-FIRED RESPOND
#      0.983   MOTOR                  PUNCH HAND LEFT FINGER INDEX
#      1.243   PROCEDURAL             PRODUCTION-FIRED PREPARE-WM
#      1.243   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK6
#      1.443   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK7
#      1.443   ------                 Stopped because no events left to process
# NEW CONGRUENT SIMON TRIAL: (SHAPE SQUARE LOCATION RIGHT CUE RIGHT [VALID])
#      1.443   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION3 NIL
#      1.493   PROCEDURAL             PRODUCTION-FIRED FIND-SCREEN
#      1.578   VISION                 SET-BUFFER-CHUNK VISUAL TEXT1
#      1.628   PROCEDURAL             PRODUCTION-FIRED PROCESS-FIXATION
#      1.628   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK8
#      1.628   ------                 Stopped because no events left to process
#      1.628   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION SIMON-STIMULUS-LOCATION2 NIL
#      1.763   PROCEDURAL             PRODUCTION-FIRED FIND-SCREEN
#      1.848   VISION                 SET-BUFFER-CHUNK VISUAL SIMON-CUE1
#      1.898   PROCEDURAL             PRODUCTION-FIRED PROCESS-CUE
#      1.898   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK9
#      1.898   ------                 Stopped because no events left to process
#      1.898   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION SIMON-STIMULUS-LOCATION3 NIL
#      1.948   PROCEDURAL             PRODUCTION-FIRED FIND-SCREEN
#      2.033   VISION                 SET-BUFFER-CHUNK VISUAL SIMON-STIMULUS1
#      2.083   PROCEDURAL             PRODUCTION-FIRED PROCESS-LOCATION
#      2.133   PROCEDURAL             PRODUCTION-FIRED DONT-PROCESS-SHAPE
#      2.183   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-INTENDED-RESPONSE
#      2.183   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK10
#      2.285   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL SQUARE-RIGHT
#      2.335   PROCEDURAL             PRODUCTION-FIRED CHECK-PASS
#      2.335   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK11
#      2.385   PROCEDURAL             PRODUCTION-FIRED RESPOND
#      2.385   MOTOR                  PUNCH HAND RIGHT FINGER INDEX
#      2.625   PROCEDURAL             PRODUCTION-FIRED PREPARE-WM
#      2.625   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK12
#      2.825   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK13
#      2.825   ------                 Stopped because no events left to process

# %%
run_experiment(model="simon-model2")
# Out:
# ######### LOADED MODEL simon-model2 #########
# >> {'seed': [100, 0], 'ans': 0.5, 'le': 0.63, 'mas': 4.0, 'egs': 0.1, 'alpha': 0.1, 'imaginal-activation': 3.0, 'motor-feature-prep-time': 0.02} <<
#      0.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION0 NIL
#      0.000   VISION                 visicon-update
#      0.000   PROCEDURAL             CONFLICT-RESOLUTION
#      0.050   PROCEDURAL             PRODUCTION-FIRED PREPARE-WM
#      0.050   PROCEDURAL             CLEAR-BUFFER GOAL
#      0.050   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      0.050   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK0
#      0.050   PROCEDURAL             CONFLICT-RESOLUTION
#      0.100   PROCEDURAL             PRODUCTION-FIRED FIND-SCREEN
#      0.100   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#      0.100   PROCEDURAL             CLEAR-BUFFER VISUAL
#      0.100   PROCEDURAL             CONFLICT-RESOLUTION
#      0.185   VISION                 Encoding-complete VISUAL-LOCATION0-0 NIL
#      0.185   VISION                 SET-BUFFER-CHUNK VISUAL TEXT0
#      0.185   PROCEDURAL             CONFLICT-RESOLUTION
#      0.250   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK1
#      0.250   PROCEDURAL             CONFLICT-RESOLUTION
#      0.300   PROCEDURAL             PRODUCTION-FIRED PROCESS-FIXATION
#      0.300   PROCEDURAL             CLEAR-BUFFER VISUAL
#      0.300   PROCEDURAL             CLEAR-BUFFER GOAL
#      0.300   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK2
#      0.300   PROCEDURAL             CONFLICT-RESOLUTION
# NEW INCONGRUENT SIMON TRIAL: (SHAPE SQUARE LOCATION LEFT CUE RIGHT [VALID])
# TEST: BEFORE stroop-update-window
# TEST: AFTER stroop-update-window
#      1.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION SIMON-STIMULUS-LOCATION0 NIL
#      1.000   VISION                 visicon-update
#      1.000   PROCEDURAL             CONFLICT-RESOLUTION
# TEST: modify_cue_feature 1 visicon-id1 RIGHT
# Name                      Att  Loc             CUE    COLOR  KIND       SIZE
# ------------------------  ---  --------------  -----  -----  ---------  ----
# SIMON-STIMULUS-LOCATION0  NEW  (400 300 1080)  RIGHT  BLACK  SIMON-CUE  1.0
#      1.001   VISION                 visicon-update
#      1.001   PROCEDURAL             CONFLICT-RESOLUTION
#      1.085   VISION                 Encoding-complete VISUAL-LOCATION0-0 NIL
#      1.085   VISION                 No visual-object found
#      1.085   PROCEDURAL             CONFLICT-RESOLUTION
#      1.135   PROCEDURAL             PRODUCTION-FIRED FIND-SCREEN
#      1.135   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#      1.135   PROCEDURAL             CLEAR-BUFFER VISUAL
#      1.135   PROCEDURAL             CONFLICT-RESOLUTION
#      1.220   VISION                 Encoding-complete SIMON-STIMULUS-LOCATION0-0 NIL
#      1.220   VISION                 SET-BUFFER-CHUNK VISUAL SIMON-CUE0
#      1.220   PROCEDURAL             CONFLICT-RESOLUTION
#      1.270   PROCEDURAL             PRODUCTION-FIRED PROCESS-CUE
#      1.270   PROCEDURAL             CLEAR-BUFFER VISUAL
#      1.270   PROCEDURAL             CLEAR-BUFFER GOAL
#      1.270   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK3
#      1.270   PROCEDURAL             CONFLICT-RESOLUTION
#      1.270   ------                 Stopped because no events left to process
#      1.270   ------                 Stopped because no events left to process
# --------------------------------------------------------------------------------
# CONGRUENT (N=0): Accuracy = nan, Response Times = nan ms
# INCONGRUENT (N=0): Accuracy = nan, Response Times = nan ms

# %%
#load_model('simon-model2')
win = actr.open_exp_window("* SIMON TASK TEST *", width = 800, height = 600, visible=1)
actr.install_device(win)
task = SimonTask(setup=False)

# %%
fixation()
actr.run(10)

cue()
actr.run(10)

stimulus()
actr.run(10)
# Out:
#      4.046   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION9 NIL
#      4.046   VISION                 visicon-update
#      4.046   PROCEDURAL             CONFLICT-RESOLUTION
#      4.096   PROCEDURAL             PRODUCTION-FIRED FIND-SCREEN
#      4.096   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#      4.096   PROCEDURAL             CLEAR-BUFFER VISUAL
#      4.096   PROCEDURAL             CONFLICT-RESOLUTION
#      4.181   VISION                 Encoding-complete VISUAL-LOCATION9-0 NIL
#      4.181   VISION                 SET-BUFFER-CHUNK VISUAL TEXT3
#      4.181   PROCEDURAL             CONFLICT-RESOLUTION
#      4.231   PROCEDURAL             PRODUCTION-FIRED PROCESS-FIXATION
#      4.231   PROCEDURAL             CLEAR-BUFFER VISUAL
#      4.231   PROCEDURAL             CLEAR-BUFFER GOAL
#      4.231   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK14
#      4.231   PROCEDURAL             CONFLICT-RESOLUTION
#      4.231   ------                 Stopped because no events left to process
#      4.231   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION SIMON-STIMULUS-LOCATION6 NIL
#      4.231   VISION                 visicon-update
#      4.231   PROCEDURAL             CONFLICT-RESOLUTION
#      4.316   VISION                 Encoding-complete VISUAL-LOCATION9-0 NIL
#      4.316   VISION                 No visual-object found
#      4.316   PROCEDURAL             CONFLICT-RESOLUTION
#      4.366   PROCEDURAL             PRODUCTION-FIRED FIND-SCREEN
#      4.366   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#      4.366   PROCEDURAL             CLEAR-BUFFER VISUAL
#      4.366   PROCEDURAL             CONFLICT-RESOLUTION
#      4.451   VISION                 Encoding-complete SIMON-STIMULUS-LOCATION6-0 NIL
#      4.451   VISION                 SET-BUFFER-CHUNK VISUAL SIMON-CUE3
#      4.451   PROCEDURAL             CONFLICT-RESOLUTION
#      4.501   PROCEDURAL             PRODUCTION-FIRED PROCESS-CUE
#      4.501   PROCEDURAL             CLEAR-BUFFER VISUAL
#      4.501   PROCEDURAL             CLEAR-BUFFER GOAL
#      4.501   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK15
#      4.501   PROCEDURAL             CONFLICT-RESOLUTION
#      4.501   ------                 Stopped because no events left to process
#      4.501   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION SIMON-STIMULUS-LOCATION7 NIL
#      4.501   VISION                 visicon-update
#      4.501   PROCEDURAL             CONFLICT-RESOLUTION
#      4.551   PROCEDURAL             PRODUCTION-FIRED FIND-SCREEN
#      4.551   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#      4.551   PROCEDURAL             CLEAR-BUFFER VISUAL
#      4.551   PROCEDURAL             CONFLICT-RESOLUTION
#      4.636   VISION                 Encoding-complete SIMON-STIMULUS-LOCATION7-0 NIL
#      4.636   VISION                 SET-BUFFER-CHUNK VISUAL SIMON-STIMULUS3
#      4.636   PROCEDURAL             CONFLICT-RESOLUTION
#      4.686   PROCEDURAL             PRODUCTION-FIRED PROCESS-LOCATION
#      4.686   PROCEDURAL             CONFLICT-RESOLUTION
#      4.736   PROCEDURAL             PRODUCTION-FIRED DONT-PROCESS-SHAPE
#      4.736   PROCEDURAL             CONFLICT-RESOLUTION
#      4.786   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-INTENDED-RESPONSE
#      4.786   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      4.786   DECLARATIVE            start-retrieval
#      4.786   PROCEDURAL             CONFLICT-RESOLUTION
#      4.889   DECLARATIVE            RETRIEVED-CHUNK CIRCLE-LEFT
#      4.889   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CIRCLE-LEFT
#      4.889   PROCEDURAL             CONFLICT-RESOLUTION
#      4.939   PROCEDURAL             PRODUCTION-FIRED CHECK-PASS
#      4.939   UTILITY                PROPAGATE-REWARD 0.1
#      4.939   PROCEDURAL             CONFLICT-RESOLUTION
#      4.989   PROCEDURAL             PRODUCTION-FIRED RESPOND
#      4.989   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      4.989   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      4.989   PROCEDURAL             CLEAR-BUFFER GOAL
#      4.989   PROCEDURAL             CLEAR-BUFFER VISUAL
#      4.989   PROCEDURAL             CLEAR-BUFFER MANUAL
#      4.989   MOTOR                  PUNCH HAND LEFT FINGER INDEX
#      4.989   UTILITY                PROPAGATE-REWARD 0.1
#      4.989   PROCEDURAL             CONFLICT-RESOLUTION
#      5.039   PROCEDURAL             CONFLICT-RESOLUTION
#      5.049   PROCEDURAL             CONFLICT-RESOLUTION
#      5.139   PROCEDURAL             CONFLICT-RESOLUTION
#      5.189   PROCEDURAL             PRODUCTION-FIRED PREPARE-WM
#      5.189   PROCEDURAL             CLEAR-BUFFER GOAL
#      5.189   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      5.189   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK16
#      5.189   PROCEDURAL             CONFLICT-RESOLUTION
#      5.389   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK17
#      5.389   PROCEDURAL             CONFLICT-RESOLUTION
#      5.389   ------                 Stopped because no events left to process
# [0.888, 111, None]

# %%
# Out:
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
#      0.300   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION SIMON-STIMULUS-LOCATION0 NIL
#      0.300   VISION                 visicon-update
#      0.300   PROCEDURAL             CONFLICT-RESOLUTION
#      0.385   VISION                 Encoding-complete VISUAL-LOCATION0-0 NIL
#      0.385   VISION                 No visual-object found
#      0.385   PROCEDURAL             CONFLICT-RESOLUTION
#      0.435   PROCEDURAL             PRODUCTION-FIRED FIND-SCREEN
#      0.435   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#      0.435   PROCEDURAL             CLEAR-BUFFER VISUAL
#      0.435   PROCEDURAL             CONFLICT-RESOLUTION
#      0.520   VISION                 Encoding-complete SIMON-STIMULUS-LOCATION0-0 NIL
#      0.520   VISION                 SET-BUFFER-CHUNK VISUAL SIMON-CUE0
#      0.520   PROCEDURAL             CONFLICT-RESOLUTION
#      0.570   PROCEDURAL             PRODUCTION-FIRED PROCESS-CUE
#      0.570   PROCEDURAL             CLEAR-BUFFER VISUAL
#      0.570   PROCEDURAL             CLEAR-BUFFER GOAL
#      0.570   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK3
#      0.570   PROCEDURAL             CONFLICT-RESOLUTION
#      0.570   ------                 Stopped because no events left to process
# [0.27, 41, None]

# %%
# Out:
# Name                      Att  Loc             CUE   COLOR  KIND       SIZE
# ------------------------  ---  --------------  ----  -----  ---------  ----
# SIMON-STIMULUS-LOCATION0  T    (400 300 1080)  LEFT  BLACK  SIMON-CUE  1.0
#      0.570   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION SIMON-STIMULUS-LOCATION1 NIL
#      0.570   VISION                 visicon-update
#      0.570   PROCEDURAL             CONFLICT-RESOLUTION
#      0.620   PROCEDURAL             PRODUCTION-FIRED FIND-SCREEN
#      0.620   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#      0.620   PROCEDURAL             CLEAR-BUFFER VISUAL
#      0.620   PROCEDURAL             CONFLICT-RESOLUTION
#      0.705   VISION                 Encoding-complete SIMON-STIMULUS-LOCATION1-0 NIL
#      0.705   VISION                 SET-BUFFER-CHUNK VISUAL SIMON-STIMULUS0
#      0.705   PROCEDURAL             CONFLICT-RESOLUTION
#      0.755   PROCEDURAL             PRODUCTION-FIRED DONT-PROCESS-SHAPE
#      0.755   PROCEDURAL             CLEAR-BUFFER GOAL
#      0.755   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK4
#      0.755   PROCEDURAL             CONFLICT-RESOLUTION
#      0.755   ------                 Stopped because no events left to process
# [0.185, 35, None]

# %%
cue()
actr.run(10)
# Out:
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
#      0.300   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION SIMON-STIMULUS-LOCATION0 NIL
#      0.300   VISION                 visicon-update
#      0.300   PROCEDURAL             CONFLICT-RESOLUTION
#      0.385   VISION                 Encoding-complete VISUAL-LOCATION0-0 NIL
#      0.385   VISION                 No visual-object found
#      0.385   PROCEDURAL             CONFLICT-RESOLUTION
#      0.800   PROCEDURAL             CONFLICT-RESOLUTION
#      0.800   ------                 Stopped because no events left to process
# [0.5, 12, None]

# %%
#actr.reset()
load_model("simon-model2")
win = actr.open_exp_window("* SIMON TASK *", width = 800, height = 600, visible=True)
actr.install_device(win)
task = SimonTask(setup=False)
task.setup(win)
# Out:
# ######### LOADED MODEL simon-model2 #########
# >> {'seed': [100, 0], 'ans': 0.5, 'le': 0.63, 'mas': 4.0, 'egs': 0.1, 'alpha': 0.1, 'imaginal-activation': 3.0, 'motor-feature-prep-time': 0.02} <<
# TEST: in fixation ['* SIMON TASK *', 'vvtext-6037']
# Name  Att  Loc
# ----  ---  ----

# %%
shape = task.current_trial.stimulus.shape.upper()
location = task.current_trial.stimulus.location.upper()
kind = task.current_trial.stimulus.kind.upper()
cue = task.current_trial.stimulus.cue.upper()

# %%
actr.clear_exp_window()
# Out:
# True

# %%
item = actr.add_text_to_exp_window(task.window, "+", font_size=50,
                                                   x = 400, y = 300,
                                                   color = "black")
actr.run_n_events(1)
actr.print_visicon()
# Out:
#      0.000   ------                 Stopped because event limit reached
# Name  Att  Loc
# ----  ---  ----

# %%
actr.clear_buffer("VISUAL")
item = actr.add_visicon_features(['isa', ['simon-stimulus-location', 'simon-cue'], 'kind', 'simon-cue',
                           'screen-x', 400, 'screen-y', 300, 
                           'shape', 'arrow', 'color', 'black', 'cue', cue])
actr.run_n_events(10)
actr.print_visicon()
# Out:
#      0.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION SIMON-STIMULUS-LOCATION0 NIL
#      0.000   VISION                 visicon-update
#      0.000   PROCEDURAL             CONFLICT-RESOLUTION
#      0.000   ------                 Stopped because event limit reached
# Name                      Att  Loc             COLOR  KIND       SIZE       TEXT  WIDTH  VALUE  HEIGHT  CUE    SHAPE
# ------------------------  ---  --------------  -----  ---------  ---------  ----  -----  -----  ------  -----  -----
# SIMON-STIMULUS-LOCATION0  NEW  (400 300 1080)  BLACK  SIMON-CUE  1.0                                    RIGHT  ARROW
# VISUAL-LOCATION1          NEW  (715 626 1080)  BLACK  TEXT       3.4299998  T     29     "+"    42

# %%
actr.add_visicon_features(['isa', ['simon-stimulus-location', 'simon-stimulus'], 'kind', 'simon-stimulus',
                           'screen-x', 400, 'screen-y', 300, 
                           'shape', shape, 'color', 'black', 'location', location])
actr.run_n_events(2)
# Out:
#      0.000   VISION                 visicon-update
#      0.000   ------                 Stopped because event limit reached
# [0.0, 2, None]

# %%
actr.print_visicon()
# Out:
# Name                      Att  Loc             COLOR  KIND            SIZE       SHAPE   LOCATION  TEXT  WIDTH  VALUE  HEIGHT  CUE
# ------------------------  ---  --------------  -----  --------------  ---------  ------  --------  ----  -----  -----  ------  -----
# SIMON-STIMULUS-LOCATION0  NEW  (400 300 1080)  BLACK  SIMON-CUE       1.0        ARROW                                         RIGHT
# SIMON-STIMULUS-LOCATION1  NEW  (400 300 1080)  BLACK  SIMON-STIMULUS  1.0        SQUARE  LEFT
# SIMON-STIMULUS-LOCATION2  NEW  (400 300 1080)  BLACK  SIMON-STIMULUS  1.0        SQUARE  LEFT
# VISUAL-LOCATION1          NEW  (715 626 1080)  BLACK  TEXT            3.4299998                    T     29     "+"    42

# %%
# Out:
# ######### LOADED MODEL simon-model2 #########
# >> {'seed': [100, 0], 'ans': 0.5, 'le': 0.63, 'mas': 4.0, 'egs': 0.1, 'alpha': 0.1, 'imaginal-activation': 3.0, 'motor-feature-prep-time': 0.02} <<
# TEST: in fixation ['* SIMON TASK *', 'vvtext-6047']
# Name  Att  Loc
# ----  ---  ----
#      0.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION0 NIL
#      0.000   VISION                 visicon-update
#      0.000   PROCEDURAL             CONFLICT-RESOLUTION
#      0.050   PROCEDURAL             PRODUCTION-FIRED PREPARE-WM
#      0.050   PROCEDURAL             CLEAR-BUFFER GOAL
#      0.050   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      0.050   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK0
#      0.050   PROCEDURAL             CONFLICT-RESOLUTION
#      0.100   PROCEDURAL             PRODUCTION-FIRED FIND-SCREEN
#      0.100   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#      0.100   PROCEDURAL             CLEAR-BUFFER VISUAL
#      0.100   PROCEDURAL             CLEAR-BUFFER GOAL
#      0.100   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK1
#      0.100   PROCEDURAL             CONFLICT-RESOLUTION
#      0.185   VISION                 Encoding-complete VISUAL-LOCATION0-0 NIL
#      0.185   VISION                 SET-BUFFER-CHUNK VISUAL TEXT0
#      0.185   PROCEDURAL             CONFLICT-RESOLUTION
#      0.250   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK2
#      0.250   PROCEDURAL             CONFLICT-RESOLUTION
# NEW INCONGRUENT SIMON TRIAL: (SHAPE SQUARE LOCATION LEFT CUE RIGHT [VALID])
# TEST: in cue ['VISICON-ID1']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID2']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID3']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID4']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID5']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID6']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID7']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID8']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID9']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID10']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID11']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID12']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID13']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID14']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID15']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID16']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID17']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID18']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID19']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID20']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID21']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID22']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID23']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID24']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID25']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID26']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID27']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID28']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID29']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID30']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID31']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID32']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID33']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID34']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID35']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID36']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID37']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID38']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID39']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID40']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID41']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID42']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID43']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID44']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID45']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID46']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID47']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID48']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID49']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID50']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID51']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID52']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID53']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID54']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID55']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID56']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID57']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID58']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID59']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID60']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID61']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID62']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID63']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID64']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID65']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID66']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID67']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID68']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID69']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID70']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID71']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID72']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID73']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID74']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID75']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID76']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID77']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID78']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID79']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID80']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID81']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID82']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID83']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID84']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID85']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID86']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID87']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID88']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID89']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID90']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID91']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID92']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID93']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID94']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID95']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID96']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID97']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID98']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID99']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID100']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID101']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID102']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID103']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID104']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID105']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID106']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID107']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID108']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID109']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID110']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID111']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID112']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID113']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID114']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID115']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID116']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID117']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID118']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID119']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID120']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID121']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID122']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID123']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID124']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID125']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID126']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID127']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID128']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID129']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID130']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID131']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID132']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID133']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID134']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID135']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID136']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID137']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID138']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID139']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID140']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID141']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID142']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID143']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID144']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID145']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID146']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# VISUAL-LOCATION0  T    (715 626 1080)  T     TEXT  BLACK  29     "+"    42      3.4299998
# UPDATE window
# TEST: in cue ['VISICON-ID147']
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE  HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----  ------  ---------
# ...
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe367cad100>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe367cad2c0>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe367cad440>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe367cade00>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe367cada40>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36794e700>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36794e2c0>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36437e940>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe367954e80>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe367954d80>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe367954800>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe367954e40>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe367cca640>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe367ccaec0>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe367ccaa80>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36795df00>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36795db80>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36795de00>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36795da40>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36795d780>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36795dd80>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe367cb7280>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe367cb7180>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36795db40>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36795d600>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36795d840>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36795d440>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36795d3c0>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36795da40>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36795d0c0>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36795de80>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36795dd40>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36795d8c0>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36795dbc0>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36795df00>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36795d100>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe367ccaf00>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe367ccaec0>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe367ccac80>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe3678871c0>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36437ebc0>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe36437e980>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe367cad300>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe367cad6c0>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
# #|Warning: Error "Error (<class 'NameError'>, NameError(\"name 'shape' is not defined\"), <traceback object at 0x7fe367cada80>) while evaluating a command in Python for command: stroop-modify-cue-feature, model: COMPETITIVE-SIMON-PY, parameters: []" while attempting to evaluate the form ("stroop-modify-cue-feature" NIL}) |#
#      1.001   PROCEDURAL             CONFLICT-RESOLUTION
#      1.085   VISION                 Encoding-complete VISUAL-LOCATION0-0 NIL
#      1.085   VISION                 No visual-object found
#      1.085   PROCEDURAL             CONFLICT-RESOLUTION
#      1.135   PROCEDURAL             PRODUCTION-FIRED FIND-SCREEN
#      1.135   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#      1.135   PROCEDURAL             CLEAR-BUFFER VISUAL
#      1.135   PROCEDURAL             CLEAR-BUFFER GOAL
#      1.135   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK3
#      1.135   PROCEDURAL             CONFLICT-RESOLUTION
#      1.220   VISION                 Encoding-complete SIMON-STIMULUS-LOCATION580-0 NIL
#      1.220   VISION                 SET-BUFFER-CHUNK VISUAL SIMON-CUE0
#      1.220   PROCEDURAL             CONFLICT-RESOLUTION
#      1.270   PROCEDURAL             PRODUCTION-FIRED PROCESS-CUE
#      1.270   PROCEDURAL             CLEAR-BUFFER VISUAL
#      1.270   PROCEDURAL             CONFLICT-RESOLUTION
#      1.270   ------                 Stopped because no events left to process
